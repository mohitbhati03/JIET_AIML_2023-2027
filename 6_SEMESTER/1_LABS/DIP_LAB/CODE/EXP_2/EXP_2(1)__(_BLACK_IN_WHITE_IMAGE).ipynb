# %% [markdown]
# .
#
#
#
#
# EXP 2
#
#
#
#
#
#
#
#
# .

# %%
#2A
import cv2
img1 = cv2.imread("CAMERAMAN_TIF.png",) #image path

img2 = cv2.threshold(img1,127,255, cv2.THRESH_BINARY)
cv2_imshow(img2[1])
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>
