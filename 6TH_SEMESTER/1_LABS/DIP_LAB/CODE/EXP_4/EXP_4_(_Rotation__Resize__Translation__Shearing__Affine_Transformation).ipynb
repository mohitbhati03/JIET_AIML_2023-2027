# %% [markdown]
# .
#
#
#
#
# EXP 4
#
#
#
#
#
#
#
#
# .

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img = cv2.imread("IMAGE.jpg")
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
h, w = img.shape[:2]

plt.imshow(img)
plt.title("Original Image")
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(200.5), np.float64(250.5), np.float64(-0.5))

# %%
# Rotation (45 degrees)
M = cv2.getRotationMatrix2D((w//2, h//2), 45, 1)
rotated = cv2.warpAffine(img, M, (w, h))

plt.imshow(rotated)
plt.title("Rotated 45 Degrees")
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(200.5), np.float64(250.5), np.float64(-0.5))

# %%
# Resize (50%)
resized = cv2.resize(img, None, fx=0.5, fy=0.5)

plt.imshow(resized)
plt.title("Resized 50%")
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(99.5), np.float64(125.5), np.float64(-0.5))

# %%
# Translation (50, 50)

M = np.float32([[1, 0, 50], [0, 1, 50]])
translated = cv2.warpAffine(img, M, (w, h))

plt.imshow(translated)
plt.title("Translated (50,50)")
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(200.5), np.float64(250.5), np.float64(-0.5))

# %%
# Shearing (factor 0.5)

M = np.float32([[1, 0.5, 0], [0, 1, 0]])
sheared = cv2.warpAffine(img, M, (w, h))

plt.imshow(sheared)
plt.title("Sheared (0.5)")
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(200.5), np.float64(250.5), np.float64(-0.5))

# %%
# Affine Transformation

pts1 = np.float32([[50,50],[200,50],[50,200]])
pts2 = np.float32([[10,100],[200,50],[100,250]])

M = cv2.getAffineTransform(pts1, pts2)
affine = cv2.warpAffine(img, M, (w, h))

plt.imshow(affine)
plt.title("Affine Transformation")
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(200.5), np.float64(250.5), np.float64(-0.5))
